# %%
import streamlit as st
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# Load the dataset
@st.cache
def load_data():
    return pd.read_csv("heart_disease_data.csv")

# Preprocess the data
def preprocess_data(df):
    # Handle categorical columns
    label_encoder = LabelEncoder()
    df['sex'] = label_encoder.fit_transform(df['sex'])
    df['fbs'] = label_encoder.fit_transform(df['fbs'])
    df['exang'] = label_encoder.fit_transform(df['exang'])
    
    return df

# Train the model
def train_model(X, y):
    model = RandomForestClassifier()
    model.fit(X, y)
    return model

# Main function to run the app
def main():
    # Page title
    st.title("Heart Disease Prediction")

    # Load data
    data = load_data()

    # Preprocess data
    data_processed = preprocess_data(data.drop(columns=['target']))

    # Train model
    X = data_processed.drop(columns=['target'])
    y = data['target']
    model = train_model(X, y)

    # Sidebar with user inputs
    st.sidebar.title("Enter Patient Information")
    age = st.sidebar.slider("Age", min_value=0, max_value=100, step=1)
    sex = st.sidebar.selectbox("Sex", ["Male", "Female"])
    cp = st.sidebar.selectbox("Chest Pain Type", [1, 2, 3, 4])
    trestbps = st.sidebar.slider("Resting Blood Pressure (mm Hg)", min_value=0, max_value=300, step=1)
    chol = st.sidebar.slider("Serum Cholesterol (mg/dl)", min_value=0, max_value=600, step=1)
    fbs = st.sidebar.selectbox("Fasting Blood Sugar > 120 mg/dl", ["Yes", "No"])
    restecg = st.sidebar.selectbox("Resting Electrocardiographic Results", [0, 1, 2])
    thalach = st.sidebar.slider("Maximum Heart Rate Achieved", min_value=0, max_value=300, step=1)
    exang = st.sidebar.selectbox("Exercise Induced Angina", ["Yes", "No"])
    oldpeak = st.sidebar.slider("ST Depression Induced by Exercise Relative to Rest", min_value=0.0, max_value=10.0, step=0.1)
    slope = st.sidebar.selectbox("Slope of the Peak Exercise ST Segment", [0, 1, 2])
    ca = st.sidebar.slider("Number of Major Vessels Colored by Fluoroscopy", min_value=0, max_value=4, step=1)
    thal = st.sidebar.selectbox("Thalassemia Type", [0, 1, 2, 3])

    # Make prediction
    patient_info = [[age, 1 if sex == "Male" else 0, cp, trestbps, chol, 1 if fbs == "Yes" else 0, restecg, thalach, 1 if exang == "Yes" else 0, oldpeak, slope, ca, thal]]
    prediction = model.predict(patient_info)

    # Display prediction
    st.subheader("Prediction:")
    if prediction[0] == 0:
        st.write("The patient is predicted to not have heart disease.")
    else:
        st.write("The patient is predicted to have heart disease.")

if __name__ == "__main__":
    main()
# Out:
# 2024-03-25 16:17:36.087
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\USER\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:361, in _CodeHasher.to_bytes(self, obj, context)
#     359 try:
#     360     # Hash the input
# --> 361     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     363     # Hmmm... It's possible that the size calculation is wrong. When we
#     364     # call to_bytes inside _to_bytes things get double-counted.
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:622, in _CodeHasher._to_bytes(self, obj, context)
#     621 assert code is not None
# --> 622 if self._file_should_be_hashed(code.co_filename):
#     623     context = _get_context(obj)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:403, in _CodeHasher._file_should_be_hashed(self, filename)
#     401     return False
#     402 return file_util.file_is_in_folder_glob(
# --> 403     filepath, self._get_main_script_directory()
#     404 ) or file_util.file_in_pythonpath(filepath)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:709, in _CodeHasher._get_main_script_directory()
#     707 # This works because we set __main__.__file__ to the
#     708 # script path in ScriptRunner.
# --> 709 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     710 return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# Cell In[1], line 72
#      69         st.write("The patient is predicted to have heart disease.")
#      71 if __name__ == "__main__":
# ---> 72     main()
#
# Cell In[1], line 34, in main()
#      31 st.title("Heart Disease Prediction")
#      33 # Load data
# ---> 34 data = load_data()
#      36 # Preprocess data
#      37 data_processed = preprocess_data(data.drop(columns=['target']))
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\caching.py:716, in cache.<locals>.wrapped_func(*args, **kwargs)
#     714 if show_spinner:
#     715     with spinner(message, cache=True):
# --> 716         return get_or_create_cached_value()
#     717 else:
#     718     return get_or_create_cached_value()
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\caching.py:638, in cache.<locals>.wrapped_func.<locals>.get_or_create_cached_value()
#     631 nonlocal cache_key
#     632 if cache_key is None:
#     633     # Delay generating the cache key until the first call.
#     634     # This way we can see values of globals, including functions
#     635     # defined after this one.
#     636     # If we generated the key earlier we would only hash those
#     637     # globals by name, and miss changes in their code or value.
# --> 638     cache_key = _hash_func(non_optional_func, hash_funcs)
#     640 # First, get the cache that's attached to this function.
#     641 # This cache's key is generated (above) from the function's code.
#     642 mem_cache = _mem_caches.get_cache(cache_key, max_entries, ttl)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\caching.py:768, in _hash_func(func, hash_funcs)
#     757 update_hash(
#     758     (func.__module__, func.__qualname__),
#     759     hasher=func_hasher,
#    (...)
#     762     hash_source=func,
#     763 )
#     765 # Include the function's body in the hash. We *do* pass hash_funcs here,
#     766 # because this step will be hashing any objects referenced in the function
#     767 # body.
# --> 768 update_hash(
#     769     func,
#     770     hasher=func_hasher,
#     771     hash_funcs=hash_funcs,
#     772     hash_reason=HashReason.CACHING_FUNC_BODY,
#     773     hash_source=func,
#     774 )
#     775 cache_key = func_hasher.hexdigest()
#     776 _LOGGER.debug(
#     777     "mem_cache key for %s.%s: %s", func.__module__, func.__qualname__, cache_key
#     778 )
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:109, in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     106 hash_stacks.current.hash_source = hash_source
#     108 ch = _CodeHasher(hash_funcs)
# --> 109 ch.update(hasher, val, context)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:386, in _CodeHasher.update(self, hasher, obj, context)
#     384 def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     385     """Update the provided hasher with the hash of an object."""
# --> 386     b = self.to_bytes(obj, context)
#     387     hasher.update(b)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:375, in _CodeHasher.to_bytes(self, obj, context)
#     372     raise
#     374 except Exception as ex:
# --> 375     raise InternalHashError(ex, obj)
#     377 finally:
#     378     # In case an UnhashableTypeError (or other) error is thrown, clean up the
#     379     # stack so we don't get false positives in future hashing calls
#     380     hash_stacks.current.pop()
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:361, in _CodeHasher.to_bytes(self, obj, context)
#     357 hash_stacks.current.push(obj)
#     359 try:
#     360     # Hash the input
# --> 361     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     363     # Hmmm... It's possible that the size calculation is wrong. When we
#     364     # call to_bytes inside _to_bytes things get double-counted.
#     365     self.size += sys.getsizeof(b)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:622, in _CodeHasher._to_bytes(self, obj, context)
#     620 code = getattr(obj, "__code__", None)
#     621 assert code is not None
# --> 622 if self._file_should_be_hashed(code.co_filename):
#     623     context = _get_context(obj)
#     624     defaults = getattr(obj, "__defaults__", None)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:403, in _CodeHasher._file_should_be_hashed(self, filename)
#     400 if file_is_blacklisted:
#     401     return False
#     402 return file_util.file_is_in_folder_glob(
# --> 403     filepath, self._get_main_script_directory()
#     404 ) or file_util.file_in_pythonpath(filepath)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\legacy_caching\hashing.py:709, in _CodeHasher._get_main_script_directory()
#     705 import __main__
#     707 # This works because we set __main__.__file__ to the
#     708 # script path in ScriptRunner.
# --> 709 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     710 return str(abs_main_path.parent)
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x000001CC025C2160>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.
